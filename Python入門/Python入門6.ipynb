# %%
x = -1

if x < 0:
    print('ゼロより小さいですよ！')
# Out:
# ゼロより小さいですよ！

# %%
x = 2

if x < 0:
    print('ゼロより小さいですよ！')

# %%
x = 1

if x < 0:
    print('ゼロより小さいです！')
elif x > 0:
    print('ゼロより大きいですよ！')
# Out:
# ゼロより大きいですよ！

# %%
x = 1

if x < 0:
    print('ゼロより小さいです！')
elif x > 0:
    print('ゼロより大きいですよ！')
else:
    print('これはゼロです！！！')
# Out:
# ゼロより大きいですよ！
