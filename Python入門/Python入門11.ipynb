# %%
l = []

for i in range(5):
    l.append(i)

print(l)
# Out:
# [0, 1, 2, 3, 4]

# %%
l = [i for i in range(5)]
print(l)
# Out:
# [0, 1, 2, 3, 4]

# %%
l = [i for i in range(5) if i % 2 == 0]
print(l)
# Out:
# [0, 2, 4]
