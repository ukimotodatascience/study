# %%
d = {'apple':80, 'banana':100}

print(d)
print(type(d))
# Out:
# {'apple': 80, 'banana': 100}
# <class 'dict'>

# %%
print(d['apple'])
print(d['banana'])
# Out:
# 80
# 100

# %%
d['banana'] = 120

print(d)
# Out:
# {'apple': 80, 'banana': 120}

# %%
d['peach'] = 150

print(d)
# Out:
# {'apple': 80, 'banana': 120, 'peach': 150}

# %%
d = {'apple':80, 'banana':100, 'peach':150}

print(d)
# Out:
# {'apple': 80, 'banana': 100, 'peach': 150}

# %%
d.keys()
# Out:
# dict_keys(['apple', 'banana', 'peach'])

# %%
for key in d.keys():
    print(key)
# Out:
# apple
# banana
# peach

# %%
d.values()
# Out:
# dict_values([80, 100, 150])

# %%
for value in d.values():
    print(value)
# Out:
# 80
# 100
# 150

# %%
d.items()
# Out:
# dict_items([('apple', 80), ('banana', 100), ('peach', 150)])

# %%
for key, value in d.items():
    print(key, value)
# Out:
# apple 80
# banana 100
# peach 150

# %%
d.items()
# Out:
# dict_items([('apple', 80), ('banana', 100), ('peach', 150)])

# %%
t = (1,2)

one, two = t

print(one, two)
# Out:
# 1 2

# %%
d = {'apple':80, 'banana':100, 'peach':150}

print(d['apple'])
# Out:
# 80

# %%
print(d)

print(d.get('apple'))
# Out:
# {'apple': 80, 'banana': 100, 'peach': 150}
# 80

# %%
print(d.get('meron'))
# Out:
# None

# %%
print(d['meron'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-b5fa5eced817> in <module>
# ----> 1 print(d['meron'])
#
# KeyError: 'meron'

# %%
d = {'apple':80, 'banana':100, 'peach':150}

print(d['apple'])
print(d.pop('apple'))
#値を取得した後、その要素を削除する
# Out:
# 80
# 80

# %%
print(d)
# Out:
# {'banana': 100, 'peach': 150}
