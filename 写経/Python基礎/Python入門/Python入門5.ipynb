# %%
a = 2
print(type(a))
# Out:
# Error in type(a): could not find function "type"
# Traceback:
#
# 1. print(type(a))

# %%
six = 6
pi = 3.14
text = 'テキスト'
is_false = FALSE

# %%
print(type(six))
print(type(pi))
print(type(text))
print(type(is_false))
# Out:
# Error in type(six): could not find function "type"
# Traceback:
#
# 1. print(type(six))

# %%
three = 3

print(type('three'))
print(three)

three_str = str(three)

print(type('three_str'))
print(three_str)
# Out:
# Error in type("three"): could not find function "type"
# Traceback:
#
# 1. print(type("three"))
