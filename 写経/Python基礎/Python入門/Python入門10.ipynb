# %%
l = [1,2,3]
print(l)

l.append(4)

print(l)
# Out:
# [1, 2, 3]
# [1, 2, 3, 4]

# %%
l = []

for i in range(5):
    l.append(i)
print(l)
# Out:
# [0, 1, 2, 3, 4]

# %%
l = [1,2,3]

#1番目に10を入れる
l.insert(1,10)

print(l)
# Out:
# [1, 10, 2, 3]

# %%
l1 = [1,2,3]
l2 = [4,5,6]

l1.extend(l2)

print(l1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l = [1,2,3,10]

print(l)

l.remove(10)

print(l)
# Out:
# [1, 2, 3, 10]
# [1, 2, 3]

# %%
l = [1,10,2,3,10]

print(l)

#最初にヒットしたもののみ削除する
l.remove(10)

print(l)
# Out:
# [1, 10, 2, 3, 10]
# [1, 2, 3, 10]
