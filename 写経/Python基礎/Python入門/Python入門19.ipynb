# %%
class Child(object):
    def __init__(self):
        print('Waaa!!!')
        
    def say_hello(self):
        print('yeah!!!')

# %%
child = Child()
# Out:
# Waaa!!!

# %%
class Child(object):
    def __init__(self,name):
        self.name = name
        print('My name is', self.name)

    def say_hello(self):
        print('yeah!!!')

child = Child('Taro')
# Out:
# My name is Taro

# %%
class Child(object):
    def __init__(self,name):
        self.name = name
        print('My name is', self.name)

    def say_hello(self):
        print('yeah!!!', self.name)

child = Child('Taro')
child.say_hello()
# Out:
# My name is Taro
# yeah!!! Taro

# %%
class Child(object):
    def __init__(self,name):
        self.name = name
        print('My name is', self.name)

    def say_hello(self):
        print('yeah!!!', name)

child = Child('Taro')
child.say_hello()
# Out:
# My name is Taro
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5edcb4be1178> in <module>
#       8
#       9 child = Child('Taro')
# ---> 10 child.say_hello()
#
# <ipython-input-5-5edcb4be1178> in say_hello(self)
#       5
#       6     def say_hello(self):
# ----> 7         print('yeah!!!', name)
#       8
#       9 child = Child('Taro')
#
# NameError: name 'name' is not defined

# %%
class Child(object):
    def __init__(self):
        print(self)

child = Child()
# Out:
# <__main__.Child object at 0x7fb4bdeff490>

# %%
print(child)
# Out:
# <__main__.Child object at 0x7fb4bdeff490>
