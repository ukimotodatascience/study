# %% [markdown]
# Pythonによるディープラーニングの作り方～画像認識～
#
# https://youtu.be/ThKRS7B5GFY?si=-lLQEl7AGt-a9BtI

# %%
#ライブラリのインポート
import numpy as np
import tensorflow as tf
import glob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# h:\マイドライブ\DataScience\アウトプット\写経\画像認識\Pythonによるディープラーニングの作り方.ipynb セル 2 line 3
#       <a href='vscode-notebook-cell:/h%3A/%E3%83%9E%E3%82%A4%E3%83%89%E3%83%A9%E3%82%A4%E3%83%96/DataScience/%E3%82%A2%E3%82%A6%E3%83%88%E3%83%97%E3%83%83%E3%83%88/%E5%86%99%E7%B5%8C/%E7%94%BB%E5%83%8F%E8%AA%8D%E8%AD%98/Python%E3%81%AB%E3%82%88%E3%82%8B%E3%83%87%E3%82%A3%E3%83%BC%E3%83%97%E3%83%A9%E3%83%BC%E3%83%8B%E3%83%B3%E3%82%B0%E3%81%AE%E4%BD%9C%E3%82%8A%E6%96%B9.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> #ライブラリのインポート
# ...

# %%
#画像データの準備
X_train = []
y_train = []
X_test = []
y_test = []

for f in glob.glob('image/*/*/*.jpg'):
    img_data = tf.io.read_file(f)   #画像データの読み込み
    img_data = tf.io.decode_jpeg(img_data)  #画像データを数値型に変換
    img_data = tf.image.resize(img_data,[100,100])

    if f.split('/')[1] == 'train':
        X_train.append(img_data)
        y_train.append(int(f.split('/')[2].split('_')[0]))

X_train = np.array(X_train) / 255
y_train = np.array(y_train)
X_test = np.array(X_test) / 255
y_test = np.array(y_test)

# %%
#ニューラルネットワークの構築
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(100,100,3)),
    tf.keras.layers.Dense(64,activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(3,activation='softmax')
])

# %%
#モデルの学習
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model.fit(X_train,y_train,epochs=10)

# %%
#モデルの評価
model.evaluate(X_test,y_test)

# %%
model.predict(X_test)
y_test
