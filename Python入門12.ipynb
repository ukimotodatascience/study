# %%
#タプルは中身の変更ができない
t = (1,2,3)

print(t)

print(type(t))
# Out:
# (1, 2, 3)
# <class 'tuple'>

# %%
t[0]
# Out:
# 1

# %%
import os

import pandas as pd
import numpy as np

KEY_TUPLE = (access_token, apl_key, xxx, xx)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-327c8c3dff1c> in <module>
#       4 import numpy as np
#       5
# ----> 6 KEY_TUPLE = (access_token, apl_key, xxx, xx)
#
# NameError: name 'access_token' is not defined

# %%
t = (1,2)

one, two = t
print('1', one)
print('2', two)
# Out:
# 1 1
# 2 2

# %%
print(t[0])
print(t[1])
# Out:
# 1
# 2

# %%
t1 = (1,2)
t2 = (3,4)

print('t1:', id(t1))
print('t2:', id(t2))
# Out:
# t1: 139661449495008
# t2: 139661481357712

# %%
t1 = t1 + t2
print(t1)
print('t1:', id(t1))
#t1を変更できたわけではなく、t1という名前のタプルをもう一つ作成しただけ
# Out:
# (1, 2, 3, 4)
# t1: 139661449614736
