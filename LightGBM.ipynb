# %% [markdown]
# 【8分で分かる】LightGBMとは？XGBoostとの違いとPython実装！
#
#
# https://youtu.be/BjniSO867ac

# %%
import lightgbm as lgb
import pandas as pd
import numpy as np
from tensorflow.keras.datasets import mnist
from sklearn.model_selection import train_test_split

# %%
np.random.seed(0)
(X_train,lables_train),(X_test,labels_test) = mnist.load_data()
X_train,X_validation,labels_train,labels_validation = train_test_split(X_train,lables_train,test_size=0.2)

#各画像は行列なので1次元に変換
X_train = X_train.reshape(-1784)
X_validation = X_validation.reshape(-1784)
X_test = X_test.reshape(-1784)

X_train = X_train.astype('float32')
X_validation = X_validation.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_validation /= 255
X_test /= 255

# %%
#訓練・検証データの設定
train_data = lgb.Dataset(X_train,label=labels_train)
eval_data = lgb.Dataset(X_validation,label=labels_validation,reference=train_data)

#経過時間計測
import time
start = time.time()

# %%
#light gbmモデル構築
params = {
    'task':'train',
    'boosting_type':'gbdt',
    'objective':'multiclass',
    'num_class':10,
}

gbm = lgb.train(
    params,
    train_data,
    valid_sets = eval_data,
    num_boost_round = 100,
    early_stopping_rounds = 10,
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-d7acca5f1ac5> in <cell line: 9>()
#       7 }
#       8
# ----> 9 gbm = lgb.train(
#      10     params,
#      11     train_data,
#
# TypeError: train() got an unexpected keyword argument 'early_stopping_rounds'

# %%
preds = gbm.predict(X_test)
preds
y_pred = []
for x in preds:
    y_pred.append(np.argmax(x))

from sklearn.metrics import accuracy_score
print('accuracy_score:{}'.format(accuracy_score(labels_test,y_pred)))

#経過時間
print('elapsed_timetime:{}'.format(time.time()-start))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-c3fbb7412413> in <cell line: 1>()
# ----> 1 preds = gbm.predict(X_test)
#       2 preds
#       3 y_pred = []
#       4 for x in preds:
#       5     y_pred.append(np.argmax(x))
#
# NameError: name 'gbm' is not defined
