# %%
l = [1,2,3,4,5]

print(l)

print(type(l))
# Out:
# [1, 2, 3, 4, 5]
# <class 'list'>

# %%
l2 =['Python', 'Java', 'Golang']

print(l2)
# Out:
# ['Python', 'Java', 'Golang']

# %%
l3 =[1, 'Python', 'True', 33]

print(l3)
# Out:
# [1, 'Python', 'True', 33]

# %%
print(l3)

for i in range(len(l3)):
    print(l3[i])
# Out:
# [1, 'Python', 'True', 33]
# 1
# Python
# True
# 33

# %%
for v in l3:
    print(v)
# Out:
# 1
# Python
# True
# 33

# %%
l2 = ['Python', 'Java', 'Golang']

for i in range(len(l2)):
    print(i, l2[i])
# Out:
# 0 Python
# 1 Java
# 2 Golang

# %%
for i, v in enumerate(l2):
    print(i, v)
# Out:
# 0 Python
# 1 Java
# 2 Golang
