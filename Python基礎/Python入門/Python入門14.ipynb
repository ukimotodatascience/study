# %%
a = {1,2,3,4,5}

print(a)
print(type(a))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
b = {2,3,3,4,5,7,9}

print(b)

print(type(b))
# Out:
# {2, 3, 4, 5, 7, 9}
# <class 'set'>

# %%
c = {1,4,3,2}

print(c)
print(type(c))
# Out:
# {1, 2, 3, 4}
# <class 'set'>

# %%
a = {1,2,3,4,5}
print('a:',a)
b = {2,3,5,7,9}
print('b:',b)

print(a - b)
print(b - a)
print(a & b)
print(a | b)
print(a ^ b)
# Out:
# a: {1, 2, 3, 4, 5}
# b: {2, 3, 5, 7, 9}
# {1, 4}
# {9, 7}
# {2, 3, 5}
# {1, 2, 3, 4, 5, 7, 9}
# {1, 4, 7, 9}
